# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_African_countries_by_GDP_(nominal)'

# %%
table = pd.read_html(url)

# %%
len(table)
# Out:
# 9

# %%
table[0]
# Out:
#    Rank                           Country Nominal GDP(Billion US$)[5]  \
# 0     1                             Egypt                     398.397
# 1     2                           Nigeria                     390.002
# 2     3                      South Africa                     380.906
# 3     4                           Algeria                     224.107
# 4     5                          Ethiopia                     155.804
# 5     6                           Morocco                     147.343
# 6     7                             Kenya                     112.749
# 7     8                            Angola                      93.796
# 8     9                          Tanzania                      84.033
# 9    10                       Ivory Coast                      79.430
# 10   11                             Ghana                      76.628
# 11   12  Democratic Republic of the Congo                      67.512
# ...

# %%
df = table[0]

# %%
df.head()
# Out:
#   Rank       Country Nominal GDP(Billion US$)[5] Per Capita(US$)[5]
# 0    1         Egypt                     398.397           3770.133
# 1    2       Nigeria                     390.002           1755.326
# 2    3  South Africa                     380.906           6190.742
# 3    4       Algeria                     224.107           4874.706
# 4    5      Ethiopia                     155.804           1473.360

# %%
df.to_csv(r"C:\Users\Henry Oguns\Desktop\5 PROJECTS\1. DATA SCRAPPING\List Of African Countries by GDP.csv", index = False)
